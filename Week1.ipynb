# %% [markdown]
# <a href="https://colab.research.google.com/github/wahyupratama18/PCVK_Genap_2022/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Step 1**
# Import libraries

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# **Step 2 - 4**
# Reproduce images, get sizes, add lines horizontally, vertically, and diagonally

# %%
urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://placekitten.com/800/571"
]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=.5, fy=.5)

  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

  height = image_2.shape[0]
  width = image_2.shape[1]

  # horizontal
  cv.line(image_3, (0, int(height/2)), (width, int(height/2)), (255, 255, 255))

  # for y in range(width):
  #   image_3[int(height/2), y] = [255, 255, 255]

  # vertical
  cv.line(image_4, (int(width/2), 0), (int(width/2), height), (255, 255, 255))
  # for x in range(height):
  #   image_4[x, int(width/2)] = [255, 255, 255]
  
  # diagonal
  cv.line(image_5, (0,0), (width, height), (255, 255, 255))
  # for x in range(height):
  #   image_5[x, int(x)] = [255, 255, 255]

  final = cv.hconcat((image, image_2, image_3, image_4, image_5))

  cv2_imshow(final)
  print('Image resolution: h x w = ', height, ' x ', width)
  print('\n\n')
# Out:
# <PIL.Image.Image image mode=RGB size=2000x276 at 0x7F0675F69790>
# Image resolution: h x w =  276  x  400
# <PIL.Image.Image image mode=RGB size=2000x286 at 0x7F06B70F9CA0>
# Image resolution: h x w =  286  x  400
# <PIL.Image.Image image mode=RGB size=2000x286 at 0x7F066EB8CB80>
# Image resolution: h x w =  286  x  400
